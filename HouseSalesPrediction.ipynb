# %%
#Import Library

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#Read CSV

df= pd.read_csv('datasets/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#Colomn Date - Data Type change

df['date']=pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
df['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
df.loc[df['bathrooms']==0.]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 875    6306400140 2014-06-12  1095000.0         0        0.0         3064
# 1149   3421079032 2015-02-17    75000.0         1        0.0          670
# 3119   3918400017 2015-02-05   380000.0         0        0.0         1470
# 5832   5702500050 2014-11-04   280000.0         1        0.0          600
# 6994   2954400190 2014-06-24  1295650.0         0        0.0         4810
# 9773   3374500520 2015-04-29   355000.0         0        0.0         2460
# 9854   7849202190 2014-12-23   235000.0         0        0.0         1470
# 10481   203100435 2014-09-18   484000.0         1        0.0          690
# 14423  9543000205 2015-04-13   139950.0         0        0.0          844
# 19452  3980300371 2014-09-26   142000.0         0        0.0          290
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 875        4764     3.5           0     2  ...      7        3064
# ...

# %%
df.loc[df['sqft_living']>0]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13   221900.0         3       1.00         1180
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 2      5631500400 2015-02-25   180000.0         2       1.00          770
# 3      2487200875 2014-12-09   604000.0         4       3.00         1960
# 4      1954400510 2015-02-18   510000.0         3       2.00         1680
# 5      7237550310 2014-05-12  1225000.0         4       4.50         5420
# 6      1321400060 2014-06-27   257500.0         3       2.25         1715
# 7      2008000270 2015-01-15   291850.0         3       1.50         1060
# 8      2414600126 2015-04-15   229500.0         3       1.00         1780
# 9      3793500160 2015-03-12   323000.0         3       2.50         1890
# 10     1736800520 2015-04-03   662500.0         3       2.50         3560
# 11     9212900260 2014-05-27   468000.0         2       1.00         1160
# ...

# %%
df['sqft_lot'].unique()
# Out:
# array([ 5650,  7242, 10000, ...,  5813,  2388,  1076], dtype=int64)

# %%
df['waterfront'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
df['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %%
df['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13,  1], dtype=int64)

# %%
df['sqft_above'].unique()
# Out:
# array([1180, 2170,  770, 1050, 1680, 3890, 1715, 1060, 1890, 1860,  860,
#        1430, 1370, 1810, 1980, 1600, 1200, 1250, 2330, 2270, 1070, 2450,
#        1710, 1750, 1400,  790, 2570, 2320, 1190, 1510, 1090, 1280,  930,
#        2360,  890, 2620, 2600, 3595, 1570,  920, 3160,  990, 2290, 2165,
#        1640, 1000, 2130, 2830, 2250, 2420, 3250, 1850, 1590, 1260, 2519,
#        1540, 1110, 1770, 2720, 2240, 3070, 2380, 2390,  880, 1040,  910,
#        3450, 2350, 1900, 1010,  960, 2660, 1610,  765, 3520, 1290, 1960,
#        1160, 1210, 1270, 1440, 2190, 2920, 1460, 1170, 1240, 3140, 2030,
#        2310,  700, 1080, 2520, 2780, 1560, 1450, 1720, 2910, 1620, 1360,
#        2070, 2460, 1390, 2140, 1320, 1340, 1550,  940, 1380, 3670, 2370,
#        1130,  980, 3540, 2500, 1760, 1030, 1780, 3400, 2680, 1670, 2590,
#         820, 1220, 2440, 2090, 1100, 1330, 1420, 1690, 2150, 1910, 1350,
#        1940,  900, 1630, 2714,  850, 1870, 1950, 2760, 2020, 1120, 1480,
# ...

# %%
df['sqft_basement'].unique()
# Out:
# array([   0,  400,  910, 1530,  730, 1700,  300,  970,  760,  720,  700,
#         820,  780,  790,  330, 1620,  360,  588, 1510,  410,  990,  600,
#         560,  550, 1000, 1600,  500, 1040,  880, 1010,  240,  265,  290,
#         800,  540,  380,  710,  840,  770,  480,  570, 1490,  620, 1250,
#        1270,  120,  650,  180, 1130,  450, 1640, 1460, 1020, 1030,  750,
#         640, 1070,  490, 1310,  630, 2000,  390,  430,  850,  210, 1430,
#        1950,  440,  220, 1160,  860,  580, 2060, 1820, 1180,  200, 1150,
#        1200,  680,  530, 1450, 1170, 1080,  960, 1100,  280,  870,  460,
#        1400, 1320,  660, 1220,  900,  420, 1580, 1380,  475,  690,  270,
#         350,  935, 1370,  980, 1470,  160,  950,   50,  740, 1780, 1900,
#         340,  470,  370,  140, 1760,  130,  610,  520,  890, 1110,  150,
#        1720,  810,  190, 1290,  670, 1800, 1120, 1810,   60, 1050,  940,
#         310,  930, 1390, 1830, 1300,  510, 1330, 1590,  920, 1420, 1240,
# ...

# %%
#make a scatterplot
sns.lmplot(x='bedrooms', y='price', data=df)

# %%
# remove outlier
meanprice = df['price'].mean()
stdprice = df['price'].std()
toprange = meanprice + stdprice * 1.96
botrange = meanprice - stdprice * 1.96

newdf = df.copy() #to not mess up the original df
newdf = newdf.drop(newdf[newdf['price'] > toprange].index)
newdf = newdf.drop(newdf[newdf['price'] < botrange].index)


print('Mean price = '+str(meanprice))
print('Standard Deviation on price = '+ str(stdprice))
# Out:
# Mean price = 540088.1417665294
# Standard Deviation on price = 367127.1964826997

# %%
#make a scatterplot
sns.lmplot(x='bedrooms', y='price', data=newdf)

# %%
# remove outlier
meanprice = df['price'].mean()
stdprice = df['price'].std()
toprange = meanprice + stdprice * 1.96
botrange = meanprice - stdprice * 1.96

meanroom = df['bedrooms'].mean()
stdroom = df['bedrooms'].std()
toproomrange = meanroom + stdroom * 1.96
botroomrange = meanroom - stdroom * 1.96

newdf = df.copy() #to not mess up the original df
newdf = newdf.drop(newdf[newdf['price'] > toprange].index)
newdf = newdf.drop(newdf[newdf['price'] < botrange].index)

newdf = newdf.drop(newdf[newdf['bedrooms'] > toproomrange].index)
newdf = newdf.drop(newdf[newdf['bedrooms'] < botroomrange].index)

print('Mean price = '+str(meanprice))
print('Standard Deviation on price = '+ str(stdprice))

print('Mean Bed Rooms = '+str(meanroom))
print('Standard Deviation on Bed Rooms = '+ str(stdroom))
# Out:
# Mean price = 540088.1417665294
# Standard Deviation on price = 367127.1964826997
# Mean Bed Rooms = 3.37084162309721
# Standard Deviation on Bed Rooms = 0.9300618311474632

# %%
#make a scatterplot
sns.lmplot(x='bedrooms', y='price', data=newdf)

# %%
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
sns.boxplot(x='bedrooms',y='price',data=newdf)

# %%
cordf= newdf.copy()
cordf=cordf.drop(['id','floors','view','grade','sqft_above','sqft_basement','lat','long','sqft_living15','sqft_lot15','zipcode'], axis=1)
corr=cordf.corr()
plt.subplots(figsize=(13,7))
sns.heatmap(corr,vmin=-1,annot=True)

#Inference 1
#Sqft Living has higher impact on Price compared to the Lot size. This means we can have a small lot with more
#living space can get a bigger price

#Inference 2
#Number of bathrooms increase with the increase in Sqft living.
